# %%
import csv
import itertools
import functools

# %%
spamReader = csv.DictReader(open('benchmarking-simulator,2018-01-29.csv'), delimiter=',')

"""
            'benchmarking',
            'file',
            'topic',
            'description',
            'started_at_time',
            'ended_time',
            'duration_secs',
            'number_of_bytes'
"""
rows = []
for row in spamReader:
    rows.append(dict(row))
    
print(rows)
# Out:
# [{'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'read_image_from_disk', 'description': '', 'started_at_time': '1517223210.7511168', 'ended_time': '1517223210.755555', 'duration_secs': '0.004438161849975586', 'number_of_bytes': '-1'}, {'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'image_binning', 'description': '', 'started_at_time': '1517223210.7556143', 'ended_time': '1517223210.7556152', 'duration_secs': '9.5367431640625e-07', 'number_of_bytes': '-1'}, {'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'image_to_bytes', 'description': '', 'started_at_time': '1517223210.755636', 'ended_time': '1517223210.8061237', 'duration_secs': '0.05048775672912598', 'number_of_bytes': '-1'}, {'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'prepare_image_bytes_method', 'description': '', 'started_at_time': '1517223210.7511168', 'ended_time': '1517223210.806164', 'duration_secs': '0.05504727363586426', 'number_of_bytes': '-1'}, {'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'stream_file', 'description': '', 'started_at_time': '1517223210.8063004', 'ended_time': '1517223210.8255825', 'duration_secs': '0.019282102584838867', 'number_of_bytes': '-1'}, {'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'read_image_from_disk', 'description': '', 'started_at_time': '1517223210.8357937', 'ended_time': '1517223210.8385503', 'duration_secs': '0.0027565956115722656', 'number_of_bytes': '-1'}, {'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'image_binning', 'description': '', 'started_at_time': '1517223210.8385968', 'ended_time': '1517223210.8385978', 'duration_secs': '9.5367431640625e-07', 'number_of_bytes': '-1'}, {'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'image_to_bytes', 'description': '', 'started_at_time': '1517223210.8386161', 'ended_time': '1517223210.9133723', 'duration_secs': '0.07475614547729492', 'number_of_bytes': '-1'}, {'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'prepare_image_bytes_method', 'description': '', 'started_at_time': '1517223210.8357937', 'ended_time': '1517223210.9134219', 'duration_secs': '0.07762813568115234', 'number_of_bytes': '-1'}, {'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'stream_file', 'description': '', 'started_at_time': '1517223210.913449', 'ended_time': '1517223210.9311197', 'duration_secs': '0.017670631408691406', 'number_of_bytes': '-1'}, {'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'read_image_from_disk', 'description': '', 'started_at_time': '1517223210.9412806', 'ended_time': '1517223210.943077', 'duration_secs': '0.0017964839935302734', 'number_of_bytes': '-1'}, {'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'image_binning', 'description': '', 'started_at_time': '1517223210.9431546', 'ended_time': '1517223210.9431562', 'duration_secs': '1.6689300537109375e-06', 'number_of_bytes': '-1'}, {'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'image_to_bytes', 'description': '', 'started_at_time': '1517223210.9431877', 'ended_time': '1517223211.0236406', 'duration_secs': '0.08045291900634766', 'number_of_bytes': '-1'}, {'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'prepare_image_bytes_method', 'description': '', 'started_at_time': '1517223210.9412806', 'ended_time': '1517223211.023703', 'duration_secs': '0.08242249488830566', 'number_of_bytes': '-1'}, {'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'stream_file', 'description': '', 'started_at_time': '1517223211.0237355', 'ended_time': '1517223211.0465071', 'duration_secs': '0.022771596908569336', 'number_of_bytes': '-1'}, {'benchmarking': 'benchmarking', 'file': 'siumulator_no_flask', 'topic': 'read_image_from_disk', 'description': '', 'started_at_time': '1517223211.0567033',  ...

# %%
rows.sort(key=lambda row: row['topic'])
grouped_by_topic = itertools.groupby(rows, lambda row: row['topic'])

totals = {}

for (topic, group) in grouped_by_topic:
    #print(topic)
    durations = list(map(lambda x: float(x['duration_secs']), group))
    #print(durations)
    
    #print ('total durations: ')
    total_duration = functools.reduce(lambda x, y: x + y, durations)
    print()
    totals[topic] = total_duration

print(totals)

total = totals['stream_all_images']

for k,v in totals.items():
    print(k + ' '+ str(v / total * 100) + ' %')
# Out:
# {'image_binning': 0.0005335807800292969, 'image_to_bytes': 29.0675151348114, 'prepare_image_bytes_method': 30.86083698272705, 'read_image_from_disk': 1.7312359809875488, 'stream_all_images': 45.26866602897644, 'stream_file': 9.183783769607544}
# image_binning 0.0011786978208895137 %
# image_to_bytes 64.21111484974023 %
# prepare_image_bytes_method 68.17262289764194 %
# read_image_from_disk 3.824358287649532 %
# stream_all_images 100.0 %
# stream_file 20.28728605284947 %
